# %% [markdown]
# <a href="https://colab.research.google.com/github/jainriya9/DeepFake-Detection/blob/main/Shape_Mismatch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
print(os.listdir('/content/drive/MyDrive/Celeb-DF'))
# Out:
# ['List_of_testing_videos.txt', 'Celeb-synthesis', 'Celeb-real', 'YouTube-real', 'Frames-Real', 'Frames-Fake', 'Frames-Fake-20240626T130258Z-001.zip', 'Frames-Real-20240626T130257Z-001.zip']

# %%
# Define the paths to your dataset in Google Drive
real_videos_dir = '/content/drive/MyDrive/Celeb-DF/Celeb-real'
fake_videos_dir = '/content/drive/MyDrive/Celeb-DF/Celeb-synthesis'

# Verify that the paths are correct
import os
print(os.listdir(real_videos_dir))
print(os.listdir(fake_videos_dir))
# Out:
# ['id0_0000.mp4', 'id0_0001.mp4', 'id0_0002.mp4', 'id0_0005.mp4', 'id0_0006.mp4', 'id10_0000.mp4', 'id0_0009.mp4', 'id0_0003.mp4', 'id0_0008.mp4', 'id0_0007.mp4', 'id0_0004.mp4', 'id11_0005.mp4', 'id10_0001.mp4', 'id10_0006.mp4', 'id11_0006.mp4', 'id10_0002.mp4', 'id10_0008.mp4', 'id10_0007.mp4', 'id10_0003.mp4', 'id10_0009.mp4', 'id10_0005.mp4', 'id11_0003.mp4', 'id11_0002.mp4', 'id11_0000.mp4', 'id11_0001.mp4', 'id10_0004.mp4', 'id11_0004.mp4', 'id12_0004.mp4', 'id13_0005.mp4', 'id13_0008.mp4', 'id13_0000.mp4', 'id11_0008.mp4', 'id13_0007.mp4', 'id13_0009.mp4', 'id13_0006.mp4', 'id11_0010.mp4', 'id12_0000.mp4', 'id12_0001.mp4', 'id13_0004.mp4', 'id11_0009.mp4', 'id13_0001.mp4', 'id12_0003.mp4', 'id11_0007.mp4', 'id12_0006.mp4', 'id13_0003.mp4', 'id12_0005.mp4', 'id13_0002.mp4', 'id12_0002.mp4', 'id13_0015.mp4', 'id13_0014.mp4', 'id16_0003.mp4', 'id13_0013.mp4', 'id13_0010.mp4', 'id16_0000.mp4', 'id13_0012.mp4', 'id16_0001.mp4', 'id16_0002.mp4', 'id13_0011.mp4', 'id17_0006.mp4', 'id16_0005.mp4', 'id16_0008.mp4', 'id17_0007.mp4', 'id16_0009.mp4', 'id17_0005.mp4', 'id16_0004.mp4', 'id16_0012.mp4', 'id17_0003.mp4', 'id16_0010.mp4', 'id16_0013.mp4', 'id17_0004.mp4', 'id17_0000.mp4', 'id16_0011.mp4', 'id17_0001.mp4', 'id17_0002.mp4', 'id16_0006.mp4', 'id16_0007.mp4', 'id2_0005.mp4', 'id2_0008.mp4', 'id1_0001.mp4', 'id2_0007.mp4', 'id17_0009.mp4', 'id1_0000.mp4', 'id1_0005.mp4', 'id2_0002.mp4', 'id1_0006.mp4', 'id17_0008.mp4', 'id1_0002.mp4', 'id1_0007.mp4', 'id2_0003.mp4', 'id1_0009.mp4', 'id1_0008.mp4', 'id2_0006.mp4', 'id1_0003.mp4', 'id2_0000.mp4', 'id2_0004.mp4', 'id1_0004.mp4', 'id2_0001.mp4', 'id2_0009.mp4', 'id3_0009.mp4', 'id3_0001.mp4', 'id3_0003.mp4', 'id4_0003.mp4', 'id3_0005.mp4', 'id3_0000.mp4', 'id3_0004.mp4', 'id4_0001.mp4', 'id3_0006.mp4', 'id4_0002.mp4', 'id3_0007.mp4', 'id4_0000.mp4', 'id3_0002.mp4', 'id3_0008.mp4', 'id6_0002.mp4', 'id4_0009.mp4', 'id6_0003.mp4', 'id4_0006.mp4', 'id6_0001.mp4', 'id4_0007.mp4', 'id6_0000.mp4', 'id6_0005.mp4', 'id4_0004.mp4', 'id4_0005.mp4', 'id6_0004.mp4', 'id4_0008.mp4', 'id6_0006.mp4', 'id7_0007.mp4', 'id8_0002.mp4', 'id7_0005.mp4', 'id7_0004.mp4', 'id8_0003.mp4', 'id7_0009.mp4', 'id7_0001.mp4', 'id7_0000.mp4', 'id6_0007.mp4', 'id8_0004.mp4', 'id8_0000.mp4', 'id8_0005.mp4', 'id7_0002.mp4', 'id8_0001.mp4', 'id7_0006.mp4', 'id7_0003.mp4', 'id7_0008.mp4', 'id6_0008.mp4', 'id6_0009.mp4', 'id9_0001.mp4', 'id9_0002.mp4', 'id9_0000.mp4', 'id8_0006.mp4', 'id9_0006.mp4', 'id8_0007.mp4', 'id9_0005.mp4', 'id9_0004.mp4', 'id8_0008.mp4', 'id9_0003.mp4', 'id8_0009.mp4', 'id9_0009.mp4', 'id9_0008.mp4', 'id9_0007.mp4']
# ['id0_id16_0008.mp4', 'id0_id16_0007.mp4', 'id0_id16_0004.mp4', 'id0_id16_0005.mp4', 'id0_id16_0006.mp4', 'id0_id16_0003.mp4', 'id0_id16_0000.mp4', 'id0_id16_0001.mp4', 'id0_id16_0002.mp4', 'id0_id1_0001.mp4', 'id0_id17_0006.mp4', 'id0_id17_0009.mp4', 'id0_id1_0005.mp4', 'id0_id17_0002.mp4', 'id0_id17_0001.mp4', 'id0_id1_0002.mp4', 'id0_id1_0006.mp4', 'id0_id17_0003.mp4', 'id0_id16_0009.mp4', 'id0_id1_0000.mp4', 'id0_id17_0005.mp4', 'id0_id17_0007.mp4', 'id0_id1_0003.mp4', 'id0_id1_0007.mp4', 'id0_id17_0000.mp4', 'id0_id2_0008.mp4', 'id0_id2_0003.mp4', 'id0_id2_0007.mp4', 'id0_id2_0009.mp4', 'id0_id3_0000.mp4', 'id0_id2_0004.mp4', 'id0_id2_0005.mp4', 'id0_id1_0009.mp4', 'id0_id2_0006.mp4', 'id0_id2_0001.mp4', 'id0_id2_0000.mp4', 'id0_id2_0002.mp4', 'id0_id3_0002.mp4', 'id0_id4_0000.mp4', 'id0_id3_0004.mp4', 'id0_id4_0001.mp4', 'id0_id3_0008.mp4', 'id0_id3_0005.mp4', 'id0_id3_0006.mp4', 'id0_id3_0001.mp4', 'id0_id3_0009.mp4', 'id0_id3_0003.mp4', 'id0_id3_0007.mp4', 'id0_id6_0006.mp4', 'id0_id4_0006.mp4', 'id0_id9_0005.mp4', 'id0_id4_0003.mp4', 'id0_id6_0000.mp4', 'id0_id9_0002.mp4', 'id0_id9_0001.mp4', 'id0_id6_0002.mp4', 'id0_id6_0001.mp4', 'id0_id6_0007.mp4', 'id0_id4_0005.mp4', 'id0_id9_0000.mp4', 'id0_id9_0003.mp4', 'id0_id9_0006.mp4', 'id0_id4_0009.mp4', 'id0_id4_0002.mp4', 'id0_id4_0004.mp4', 'id0_id6_0009.mp4', 'id10_id12_0003.mp4', 'id10_id11_0001.mp4', 'id10_id12_0002.mp4', 'id0_id9_0008.mp4', 'id10_id11_0008.mp4', 'id10_id11_0005.mp4', 'id0_id9_0007.mp4', 'id10_id11_0006.mp4', 'id10_id11_0007.mp4', 'id10_id11_0004.mp4', 'id0_id9_0009.mp4', 'id10_id11_0002.mp4', 'id10_id12_0001.mp4', 'id10_id11_0003.mp4', 'id10_id7_0001.mp4', 'id10_id12_0004.mp4', 'id10_id13_0007.mp4', 'id10_id7_0002.mp4', 'id10_id13_0002.mp4', 'id10_id13_0004.mp4', 'id10_id13_0005.mp4', 'id10_id12_0007.mp4', 'id10_id12_0006.mp4', 'id10_id13_0001.mp4', 'id10_id13_0008.mp4', 'id10_id12_0008.mp4', 'id10_id13_0003.mp4', 'id10_id12_0005.mp4', 'id10_id13_0006.mp4', 'id12_id10_0004.mp4', 'id12_id10_0002.mp4', 'id11_id7_0007.mp4', 'id10_id7_0009.mp4', 'id11_id7_0005.mp4', 'id11_id7_0002.mp4', 'id10_id7_0006.mp4', 'id11_id7_0000.mp4', 'id11_id7_0003.mp4', 'id11_id7_0004.mp4', 'id11_id7_0006.mp4', 'id10_id7_0004.mp4', 'id11_id7_0010.mp4', 'id10_id7_0005.mp4', 'id11_id7_0009.mp4', 'id10_id7_0008.mp4', 'id11_id7_0001.mp4', 'id10_id7_0007.mp4', 'id10_id7_0003.mp4', 'id11_id7_0008.mp4', 'id12_id10_0001.mp4', 'id12_id7_0006.mp4', 'id13_id10_0005.mp4', 'id13_id10_0001.mp4', 'id13_id10_0003.mp4', 'id12_id7_0004.mp4', 'id12_id7_0002.mp4', 'id13_id10_0011.mp4', 'id13_id10_0007.mp4', 'id12_id10_0005.mp4', 'id12_id7_0000.mp4', 'id12_id7_0005.mp4', 'id12_id10_0006.mp4', 'id13_id10_0000.mp4', 'id13_id10_0008.mp4', 'id13_id10_0004.mp4', 'id12_id7_0001.mp4', 'id13_id7_0003.mp4', 'id13_id7_0008.mp4', 'id13_id10_0012.mp4', 'id13_id7_0004.mp4', 'id13_id7_0005.mp4', 'id13_id7_0002.mp4', 'id13_id7_0000.mp4', 'id13_id7_0011.mp4', 'id13_id7_0007.mp4', 'id13_id7_0001.mp4', 'id13_id7_0009.mp4', 'id13_id10_0014.mp4', 'id13_id10_0015.mp4', 'id16_id0_0010.mp4', 'id16_id0_0000.mp4', 'id16_id17_0004.mp4', 'id16_id17_0000.mp4', 'id16_id17_0001.mp4', 'id13_id7_0015.mp4', 'id16_id0_0006.mp4', 'id16_id0_0013.mp4', 'id16_id0_0012.mp4', 'id16_id0_0003.mp4', 'id16_id17_0005.mp4', 'id16_id0_0005.mp4', 'id16_id0_0011.mp4', 'id16_id0_0002.mp4', 'id16_id0_0004.mp4', 'id16_id0_0001.mp4', 'id16_id17_0003.mp4', 'id16_id0_0007.mp4', 'id16_id17_0002.mp4', 'id13_id7_0012.mp4', 'id16_id0_0009.mp4', 'id16_id17_0011.mp4', 'id16_id1_0006.mp4', 'id16_id17_0010.mp4', 'id16_id1_0004.mp4', 'id16_id1_0010.mp4', 'id16_id1_0000.mp4', 'id16_id17_0013.mp4', 'id16_id1_0001.mp4', 'id16_id1_0007.mp4', 'id16_id1_0002.mp4', 'id16_id17_0009.mp4', 'id16_id1_0005.mp4', 'id16_id17_0012.mp4', 'id16_id1_0011.mp4', 'id16_id1_0003.mp4', 'id16_id17_0007.mp4', 'id16_id17_0006.mp4', 'id16_id1_0009.mp4', 'id16_id2_0001.mp4', 'id16_id2_0005.mp4', 'id16_id2_0000.mp4', 'id16_id1_0013.mp4', 'id16_id2_0007.mp4', 'id16_id2_0004.mp4', 'id16_i ...

# %%
import os
import cv2

def extract_frames(video_path, output_folder, frame_interval=25):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    cap = cv2.VideoCapture(video_path)
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    for i in range(0, frame_count, frame_interval):
        cap.set(cv2.CAP_PROP_POS_FRAMES, i)
        ret, frame = cap.read()
        if ret:
            frame_filename = os.path.join(output_folder, f"{os.path.basename(video_path).split('.')[0]}_frame_{i}.jpg")
            cv2.imwrite(frame_filename, frame)
    cap.release()

# Paths to datasets
real_videos_dir = '/content/drive/MyDrive/Celeb-DF/Celeb-real'
fake_videos_dir = '/content/drive/MyDrive/Celeb-DF/Celeb-synthesis'

# Output paths for frames
real_frames_path = '/content/drive/MyDrive/Celeb-DF/Frames-Real'
fake_frames_path = '/content/drive/MyDrive/Celeb-DF/Frames-Fake'

# Extract frames from real videos
for video_file in os.listdir(real_videos_dir):
    video_path = os.path.join(real_videos_dir, video_file)
    extract_frames(video_path, real_frames_path)

# Extract frames from fake videos
for video_file in os.listdir(fake_videos_dir):
    video_path = os.path.join(fake_videos_dir, video_file)
    extract_frames(video_path, fake_frames_path)

print(f"Extracted frames saved to {real_frames_path} and {fake_frames_path}.")
# Out:
# Extracted frames saved to /content/drive/MyDrive/Celeb-DF/Frames-Real and /content/drive/MyDrive/Celeb-DF/Frames-Fake.

# %%
# Output paths for frames
real_frames_path = '/content/drive/MyDrive/Celeb-DF/Frames-Real'
fake_frames_path = '/content/drive/MyDrive/Celeb-DF/Frames-Fake'

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import os
import cv2

# Define minimal data augmentation for real frames
datagen = ImageDataGenerator(
    rotation_range=5,
    width_shift_range=0.05,
    height_shift_range=0.05,
    horizontal_flip=True
)

# Augment frames without saving
def augment_frames(image_folder):
    augmented_frames = []
    for filename in os.listdir(image_folder):
        image_path = os.path.join(image_folder, filename)
        image = cv2.imread(image_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert to RGB
        image = image.reshape((1,) + image.shape)  # Reshape for datagen
        augmented_iter = datagen.flow(image, batch_size=1)
        augmented_frames.append(next(augmented_iter)[0].astype(np.uint8))  # Take one augmented frame
    return augmented_frames

# Augment real frames only
augmented_real_frames = augment_frames(real_frames_path)

# Display the number of augmented frames
print(f"Augmented {len(augmented_real_frames)} real frames.")
# Out:
# Augmented 2538 real frames.

# %%
import librosa
import numpy as np
from scipy.fftpack import fft
from scipy.signal import butter, lfilter

def extract_mfcc_fft(image):
    image_gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    signal = image_gray.mean(axis=0)

    # High-pass filter
    cutoff_freq = 100  # Adjust this value based on your desired cutoff frequency
    nyquist_freq = 0.5 * 22050
    normal_cutoff = cutoff_freq / nyquist_freq
    b, a = butter(4, normal_cutoff, btype='high', analog=False)
    filtered_signal = lfilter(b, a, signal)

    # Adjust n_fft based on the length of filtered_signal
    n_fft = min(2048, len(filtered_signal))  # Set n_fft to be smaller of 2048 or signal length
    mfccs = librosa.feature.mfcc(y=filtered_signal, sr=22050, n_mfcc=13, n_fft=n_fft)
    fft_features = np.abs(fft(filtered_signal, n=n_fft))
    return mfccs, fft_features

# Example usage
# real_features = [extract_mfcc_fft(frame) for frame in augmented_real_frames]
# fake_features = [extract_mfcc_fft(frame) for frame in fake_frames]

# Ensure to handle varying signal lengths appropriately in your actual application.


# Extract features from augmented real frames
real_features = [extract_mfcc_fft(frame) for frame in augmented_real_frames]

# Extract features from fake frames (not augmented)
fake_features = []
for filename in os.listdir(fake_frames_path):
    image_path = os.path.join(fake_frames_path, filename)
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    mfcc, fft_features = extract_mfcc_fft(image)
    fake_features.append((mfcc, fft_features))

print(f"Extracted features from {len(real_features)} augmented real frames.")
print(f"Extracted features from {len(fake_features)} fake frames.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-81f89ea8a30b> in <cell line: 31>()
#      29
#      30 # Extract features from augmented real frames
# ---> 31 real_features = [extract_mfcc_fft(frame) for frame in augmented_real_frames]
#      32
#      33 # Extract features from fake frames (not augmented)
#
# NameError: name 'augmented_real_frames' is not defined

# %%
import numpy as np

# Assuming you have extracted features stored in real_features and fake_features
# real_features and fake_features should be lists of tuples (mfccs, fft_features)

# Pad or truncate MFCC features to a consistent length
max_length = max(len(f[0][0]) for f in real_features + fake_features)  # Find the maximum length
X_mfcc = []
for f in real_features + fake_features:
    mfcc = f[0]
    if len(mfcc[0]) < max_length:
        # Pad with zeros along the time axis
        mfcc = np.pad(mfcc, ((0, 0), (0, max_length - len(mfcc[0]))), mode='constant')
    elif len(mfcc[0]) > max_length:
        # Truncate along the time axis
        mfcc = mfcc[:, :max_length]
    X_mfcc.append(mfcc)

X_mfcc = np.array(X_mfcc)

# Pad or truncate FFT features to a consistent length
max_length_fft = max(len(f[1]) for f in real_features + fake_features)
X_fft = []
for f in real_features + fake_features:
    fft_features = f[1]
    if len(fft_features) < max_length_fft:
        # Pad with zeros
        fft_features = np.pad(fft_features, (0, max_length_fft - len(fft_features)), mode='constant')
    elif len(fft_features) > max_length_fft:
        # Truncate
        fft_features = fft_features[:max_length_fft]
    X_fft.append(fft_features)

X_fft = np.array(X_fft)

# Create labels: 0 for real, 1 for fake
y_labels = np.array([0] * len(real_features) + [1] * len(fake_features))

# %%
print("MFCCs shape:", mfcc.shape)
print("FFT features shape:", fft_features.shape)
# Out:
# MFCCs shape: (13, 2)
# FFT features shape: (974,)

# %%
# !pip install tensorflow_addons
# Out:
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (24.1)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow_addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow_addons
# Successfully installed tensorflow_addons-0.23.0 typeguard-2.13.3

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Embedding, Dense, Flatten, Concatenate, Conv2D, MaxPooling2D, Dropout, GlobalAveragePooling2D, LayerNormalization, Add
from tensorflow.keras.models import Model
import tensorflow_addons as tfa

# Assuming X_mfcc, X_fft, and y_labels are already defined as in the previous step

# --- Input Layers ---
# For MFCC features
mfcc_input = Input(shape=X_mfcc[0].shape)

# For FFT features
fft_input = Input(shape=(X_fft[0].shape))

# --- Dense Layers for MFCC ---
# Use Dense layers instead of Embedding for continuous MFCC features
mfcc_dense1 = Dense(128, activation='relu')(mfcc_input)
mfcc_dense2 = Dense(64, activation='relu')(mfcc_dense1)
mfcc_flat = Flatten()(mfcc_dense2)

# --- Dense Layer for FFT ---
fft_embedding = Dense(64, activation='relu')(fft_input)
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-66b507429859> in <cell line: 10>()
#       8 # --- Input Layers ---
#       9 # For MFCC features
# ---> 10 mfcc_input = Input(shape=X_mfcc[0].shape)
#      11
#      12 # For FFT features
#
# NameError: name 'X_mfcc' is not defined

# %%
print("MFCC input:", mfcc_input.shape)
print("fft input:", fft_input.shape)
# Out:
# MFCC input: (None, 13, 2)
# fft input: (None, 974)

# %%
def pvt_block(x, num_channels):
    # A simplified PVT block (adapt as needed)
    shortcut = x
    x = Conv2D(num_channels, kernel_size=1, strides=1, padding='same')(x)
    x = LayerNormalization()(x)
    x = tf.nn.relu(x)
    x = Conv2D(num_channels, kernel_size=3, strides=1, padding='same')(x)
    x = LayerNormalization()(x)
    x = tf.nn.relu(x)  # Continue the block here
    # Project the shortcut to match the number of channels
    shortcut = Conv2D(num_channels * 4, kernel_size=1, strides=1, padding='same')(shortcut)
    x = Conv2D(num_channels * 4, kernel_size=1, strides=1, padding='same')(x)
    x = LayerNormalization()(x)
    x = Add()([shortcut, x])
    x = tf.nn.relu(x)
    return x

# %%
from tensorflow.keras.layers import Reshape
reshaped_fft_embedding = Reshape((8, 8, 1))(fft_embedding)

# Pass the reshaped output to pvt_block
pvt_output = pvt_block(reshaped_fft_embedding, 64)

# %%
# --- Concatenate Embeddings and PVT Output ---
# Flatten pvt_output to match the shape of mfcc_flat and fft_embedding
pvt_flat = Flatten()(pvt_output)
concat = Concatenate()([mfcc_flat, fft_embedding, pvt_flat])

# --- Multimodal and Distillation Heads ---
multimodal_head = Dense(2, activation='softmax', name='multimodal_head')(concat) # Adjust num_classes
distillation_head = Dense(2, activation='softmax', name='distillation_head')(pvt_flat) # Adjust num_classes, use pvt_flat here

# --- Create the Model ---
model = Model(inputs=[mfcc_input, fft_input], outputs=[multimodal_head, distillation_head])

# --- Compile the Model ---
model.compile(
    optimizer='adam',
    loss={
        'multimodal_head': 'categorical_crossentropy',
        'distillation_head': 'categorical_crossentropy'
    },
    metrics=['accuracy'],
    run_eagerly=True
)
# --- Print Model Summary ---
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 974)]                0         []
#
#  dense_2 (Dense)             (None, 64)                   62400     ['input_2[0][0]']
#
#  reshape (Reshape)           (None, 8, 8, 1)              0         ['dense_2[0][0]']
#
#  conv2d (Conv2D)             (None, 8, 8, 64)             128       ['reshape[0][0]']
#
#  layer_normalization (Layer  (None, 8, 8, 64)             128       ['conv2d[0][0]']
#  Normalization)
#
#  tf.nn.relu (TFOpLambda)     (None, 8, 8, 64)             0         ['layer_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 64)             36928     ['tf.nn.relu[0][0]']
#
#  layer_normalization_1 (Lay  (None, 8, 8, 64)             128       ['conv2d_1[0][0]']
#  erNormalization)
#
#  tf.nn.relu_1 (TFOpLambda)   (None, 8, 8, 64)             0         ['layer_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 256)            16640     ['tf.nn.relu_1[0][0]']
#
#  input_1 (InputLayer)        [(None, 13, 2)]              0         []
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 256)            512       ['reshape[0][0]']
#
#  layer_normalization_2 (Lay  (None, 8, 8, 256)            512       ['conv2d_3[0][0]']
#  erNormalization)
#
#  dense (Dense)               (None, 13, 128)              384       ['input_1[0][0]']
#
#  add (Add)                   (None, 8, 8, 256)            0         ['conv2d_2[0][0]',
#                                                                      'layer_normalization_2[0][0]'
#                                                                     ]
#
#  dense_1 (Dense)             (None, 13, 64)               8256      ['dense[0][0]']
#
#  tf.nn.relu_2 (TFOpLambda)   (None, 8, 8, 256)            0         ['add[0][0]']
#
#  flatten (Flatten)           (None, 832)                  0         ['dense_1[0][0]']
#
#  flatten_1 (Flatten)         (None, 16384)                0         ['tf.nn.relu_2[0][0]']
#
#  concatenate (Concatenate)   (None, 17280)                0         ['flatten[0][0]',
#                                                                      'dense_2[0][0]',
#                                                                      'flatten_1[0][0]']
#
#  multimodal_head (Dense)     (None, 2)                    34562     ['concatenate[0][0]']
#
#  distillation_head (Dense)   (None, 2)                    32770     ['flatten_1[0][0]']
#
# ==================================================================================================
# Total params: 193348 (755.27 KB)
# Trainable params: 193348 (755.27 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.layers import Input, Dense, GlobalAveragePooling1D, LayerNormalization, MultiHeadAttention, Add, Lambda, Reshape
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
import tensorflow as tf
# Print model graph
plot_model(model, show_shapes=True, show_layer_names=True)

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and validation sets (adjust test_size as needed)
X_mfcc_train, X_mfcc_val, X_fft_train, X_fft_val, y_train, y_val = train_test_split(
    X_mfcc, X_fft, y_labels, test_size=0.2, random_state=42
)

# %%
# Print shapes before model compilation
print("Shapes before model compilation:")
print("X_mfcc_train shape:", X_mfcc_train.shape)
print("X_fft_train shape:", X_fft_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# Shapes before model compilation:
# X_mfcc_train shape: (12340, 13, 2)
# X_fft_train shape: (12340, 974)
# y_train shape: (12340,)

# %%
from tensorflow.keras.utils import to_categorical

# One-hot encode labels (if they are not already)
y_train = to_categorical(y_train, num_classes=2)
y_val = to_categorical(y_val, num_classes=2)

# %%
history = model.fit(
    x=[X_mfcc_train, X_fft_train],  # Provide training data for MFCC and FFT inputs
    y={'multimodal_head': y_train, 'distillation_head': y_train},  # Assuming both heads use the same labels
    epochs=30,  # Adjust the number of epochs as needed
    batch_size=4,  # Adjust the batch size as needed
    validation_data=([X_mfcc_val, X_fft_val],
                     {'multimodal_head': y_val, 'distillation_head': y_val})  # Use validation data
)
# Out:
# Epoch 1/30
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x793bcb7e48b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x793bcb7e48b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3085/3085 [==============================] - 296s 94ms/step - loss: 2.1656 - multimodal_head_loss: 1.1084 - distillation_head_loss: 1.0572 - multimodal_head_accuracy: 0.8844 - distillation_head_accuracy: 0.8525 - val_loss: 0.6438 - val_multimodal_head_loss: 0.2393 - val_distillation_head_loss: 0.4046 - val_multimodal_head_accuracy: 0.9145 - val_distillation_head_accuracy: 0.8629
# Epoch 2/30
# 3085/3085 [==============================] - 287s 93ms/step - loss: 0.7437 - multimodal_head_loss: 0.3315 - distillation_head_loss: 0.4122 - multimodal_head_accuracy: 0.8973 - distillation_head_accuracy: 0.8572 - val_loss: 0.5248 - val_multimodal_head_loss: 0.2305 - val_distillation_head_loss: 0.2943 - val_multimodal_head_accuracy: 0.9245 - val_distillation_head_accuracy: 0.9122
# Epoch 3/30
# 3085/3085 [==============================] - 287s 93ms/step - loss: 0.5660 - multimodal_head_loss: 0.2575 - distillation_head_loss: 0.3085 - multimodal_head_accuracy: 0.9225 - distillation_head_accuracy: 0.9096 - val_loss: 2.1549 - val_multimodal_head_loss: 1.6055 - val_distillation_head_loss: 0.5494 - val_multimodal_head_accuracy: 0.7074 - val_distillation_head_accuracy: 0.7975
# Epoch 4/30
# 3085/3085 [==============================] - 285s 92ms/step - loss: 0.6329 - multimodal_head_loss: 0.3226 - distillation_head_loss: 0.3104 - multimodal_head_accuracy: 0.9139 - distillation_head_accuracy: 0.8996 - val_loss: 0.4502 - val_multimodal_head_loss: 0.1838 - val_distillation_head_loss: 0.2664 - val_multimodal_head_accuracy: 0.9397 - val_distillation_head_accuracy: 0.9213
# Epoch 5/30
# 3085/3085 [==============================] - 288s 93ms/step - loss: 0.4558 - multimodal_head_loss: 0.1942 - distillation_head_loss: 0.2616 - multimodal_head_accuracy: 0.9349 - distillation_head_accuracy: 0.9229 - val_loss: 0.4665 - val_multimodal_head_loss: 0.2046 - val_distillation_head_loss: 0.2619 - val_multimodal_head_accuracy: 0.9307 - val_distillation_head_accuracy: 0.9235
# Epoch 6/30
# 3085/3085 [==============================] - 288s 93ms/step - loss: 0.4525 - multimodal_head_loss: 0.1912 - distillation_head_loss: 0.2613 - multimodal_head_accuracy: 0.9381 - distillation_head_accuracy: 0.9236 - val_loss: 0.4746 - val_multimodal_head_loss: 0.1885 - val_distillation_head_loss: 0.2861 - val_multimodal_head_accuracy: 0.9378 - val_distillation_head_accuracy: 0.9125
# Epoch 7/30
# 3085/3085 [==============================] - 286s 93ms/step - loss: 0.4557 - multimodal_head_loss: 0.1941 - distillation_head_loss: 0.2616 - multimodal_head_accuracy: 0.9404 - distillation_head_accuracy: 0.9251 - val_loss: 0.4479 - val_multimodal_head_loss: 0.1831 - val_distillation_head_loss: 0.2648 - val_multimodal_head_accuracy: 0.9381 - val_distillation_head_accuracy: 0.9222
# Epoch 8/30
# 3085/3085 [==============================] - 287s 93ms/step - loss: 0.4560 - multimodal_head_loss: 0.1963 - distillation_head_loss: 0.2597 - multimodal_head_accuracy: 0.9397 - distillation_head_accuracy: 0.9263 - val_loss: 0.4630 - val_multimodal_head_loss: 0.2001 - val_distillation_head_loss: 0.2630 - val_multimodal_head_accuracy: 0.9378 - val_distillation_head_accuracy: 0.9229
# Epoch 9/30
# 3085/3085 [==============================] - 286s 93ms/step - loss: 0.4423 - multimodal_head_loss: 0.1853 - distillation_head_loss: 0.2571 - multimodal_head_accuracy: 0.9417 - distillation_head_accuracy: 0.9250 - val_loss: 0.4333 - val_multimodal_head_loss: 0.1738 - val_distillation_head_loss: 0.2596 - val_multimodal_head_accuracy: 0.9426 - val_distillation_head_accuracy: 0.9248
# Epoch 10/30
# 3085/3085 [==============================] - 282s 91ms/step - loss: 0.4292 - multimodal_head_loss: 0.1764 - distillation_head_loss: 0.2528 - multimodal_head_accuracy: 0.9429 - distillation_head_accuracy: 0.9273 - val_loss: 0.4491 - val_multimodal_head_loss: 0.1880 - val_distillation_head_loss: 0.2610 - val_multimodal_head_accuracy: 0.9384 - val_distillation_head_accuracy: 0.9245
# Epoch 11/30
# 3085/3085 [==============================] - 276s 89ms/step - loss: 0.4298 - multimodal_head_loss: 0.1772 - distillation_head_loss: 0.2525 - multimodal_head_accuracy: 0.9473 - distillation_head_accuracy: 0.9282 - val_loss: 0.4039 - val_multimodal_head_loss: 0.1568 - val_distillation_head_loss: 0.2471 - val_multimodal_head_accuracy: 0.9524 - val_distillation_head_accuracy: 0.9284
# Epoch 12/30
# 3085/3085 [==============================] - 276s 90ms/step - loss: 0.3997 - multimodal_head_loss: 0.1574 - distillation_head_loss: 0.2422 - multimodal_head_accuracy: 0.9484 - distillation_head_accuracy: 0.9308 - val_loss: 0.4387 - val_multimodal_head_loss: 0.1847 - val_distillation_head_loss: 0.2540 - val_multimodal_head_accuracy: 0.9449 - val_distillation_head_accuracy: 0.9268
# Epoch 13/30
# 3085/3085 [==============================] - 275s 89ms/step - loss: 0.4119 - multimodal_head_loss: 0.1633 - distillation_head_loss: 0.2486 - multimodal_head_accuracy: 0.9510 - distillation_head_accuracy: 0.9294 - val_loss: 0.4315 - val_multimodal_head_loss: 0.1794 - val_distillation_head_loss: 0.2521 - val_multimodal_head_accuracy: 0.9439 - val_distillation_head_accuracy: 0.9264
# Epoch 14/30
# 3085/3085 [==============================] - 276s 90ms/step - loss: 0.4121 - multimodal_head_loss: 0.1627 - distillation_head_loss: 0.2495 - multimodal_head_accuracy: 0.9493 - distillation_head_accuracy: 0.9288 - val_loss: 0.4373 - val_multimodal_head_loss: 0.1729 - val_distillation_head_loss: 0.2644 - val_multimodal_head_accuracy: 0.9527 - val_distillation_head_accuracy: 0.9235
# Epoch 15/30
# 3085/3085 [==============================] - 274s 89ms/step - loss: 0.4052 - multimodal_head_loss: 0.1592 - distillation_head_loss: 0.2460 - multimodal_head_accuracy: 0.9500 - distillation_head_accuracy: 0.9299 - val_loss: 0.4300 - val_multimodal_head_loss: 0.1784 - val_distillation_head_loss: 0.2516 - val_multimodal_head_accuracy: 0.9439 - val_distillation_head_accuracy: 0.9268
# Epoch 16/30
# 3085/3085 [==============================] - 276s 90ms/step - loss: 0.4028 - multimodal_head_loss: 0.1570 - distillation_head_loss: 0.2458 - multimodal_head_accuracy: 0.9494 - distillation_head_accuracy: 0.9301 - val_loss: 0.4398 - val_multimodal_head_loss: 0.1863 - val_distillation_head_loss: 0.2535 - val_multimodal_head_accuracy: 0.9417 - val_distillation_head_accuracy: 0.9277
# Epoch 17/30
# 3085/3085 [==============================] - 275s 89ms/step - loss: 0.4063 - multimodal_head_loss: 0.1595 - distillation_head_loss: 0.2469 - multimodal_head_accuracy: 0.9516 - distillation_head_accuracy: 0.9293 - val_loss: 0.4148 - val_multimodal_head_loss: 0.1655 - val_distillation_head_loss: 0.2493 - val_multimodal_head_accuracy: 0.9488 - val_distillation_head_accuracy: 0.9287
# Epoch 18/30
# 3085/3085 [==============================] - 272s 88ms/step - loss: 0.3916 - multimodal_head_loss: 0.1510 - distillation_head_loss: 0.2405 - multimodal_head_accuracy: 0.9528 - distillation_head_accuracy: 0.9318 - val_loss: 0.4201 - val_multimodal_head_loss: 0.1685 - val_distillation_head_loss: 0.2516 - val_multimodal_head_accuracy: 0.9566 - val_distillation_head_accuracy: 0.9277
# Epoch 19/30
# 3085/3085 [==============================] - 276s 89ms/step - loss: 0.3954 - multimodal_head_loss: 0.1491 - distillation_head_loss: 0.2463 - multimodal_head_accuracy: 0.9529 - distillation_head_accuracy: 0.9291 - val_loss: 0.4293 - val_multimodal_head_loss: 0.1681 - val_distillation_head_loss: 0.2612 - val_multimodal_head_accuracy: 0.9462 - val_distillation_head_accuracy: 0.9232
# Epoch 20/30
# 3085/3085 [==============================] - 277s 90ms/step - loss: 0.4289 - multimodal_head_loss: 0.1772 - distillation_head_loss: 0.2517 - multimodal_head_accuracy: 0.9528 - distillation_head_accuracy: 0.9262 - val_loss: 0.4561 - val_multimodal_head_loss: 0.1640 - val_distillation_head_loss: 0.2922 - val_multimodal_head_accuracy: 0.9533 - val_distillation_head_accuracy: 0.9122
# Epoch 21/30
# 3085/3085 [==============================] - 276s 90ms/step - loss: 0.3982 - multimodal_head_loss: 0.1490 - distillation_head_loss: 0.2492 - multimodal_head_accuracy: 0.9535 - distillation_head_accuracy: 0.9296 - val_loss: 0.4224 - val_multimodal_head_loss: 0.1590 - val_distillation_head_loss: 0.2634 - val_multimodal_head_accuracy: 0.9524 - val_distillation_head_accuracy: 0.9261
# Epoch 22/30
# 3085/3085 [==============================] - 276s 89ms/step - loss: 0.3867 - multimodal_head_loss: 0.1408 - distillation_head_loss: 0.2459 - multimodal_head_accuracy: 0.9558 - distillation_head_accuracy: 0.9325 - val_loss: 0.4144 - val_multimodal_head_loss: 0.1510 - val_distillation_head_loss: 0.2634 - val_multimodal_head_accuracy: 0.9569 - val_distillation_head_accuracy: 0.9264
# Epoch 23/30
# 3085/3085 [==============================] - 277s 90ms/step - loss: 0.4063 - multimodal_head_loss: 0.1552 - distillation_head_loss: 0.2510 - multimodal_head_accuracy: 0.9515 - distillation_head_accuracy: 0.9288 - val_loss: 0.4110 - val_multimodal_head_loss: 0.1622 - val_distillation_head_loss: 0.2489 - val_multimodal_head_accuracy: 0.9540 - val_distillation_head_accuracy: 0.9284
# Epoch 24/30
# 3085/3085 [==============================] - 274s 89ms/step - loss: 0.4019 - multimodal_head_loss: 0.1531 - distillation_head_loss: 0.2488 - multimodal_head_accuracy: 0.9519 - distillation_head_accuracy: 0.9289 - val_loss: 0.4195 - val_multimodal_head_loss: 0.1649 - val_distillation_head_loss: 0.2545 - val_multimodal_head_accuracy: 0.9475 - val_distillation_head_accuracy: 0.9264
# Epoch 25/30
# 3085/3085 [==============================] - 276s 89ms/step - loss: 0.4118 - multimodal_head_loss: 0.1639 - distillation_head_loss: 0.2479 - multimodal_head_accuracy: 0.9523 - distillation_head_accuracy: 0.9281 - val_loss: 0.4063 - val_multimodal_head_loss: 0.1574 - val_distillation_head_loss: 0.2489 - val_multimodal_head_accuracy: 0.9556 - val_distillation_head_accuracy: 0.9271
# Epoch 26/30
# 3085/3085 [==============================] - 275s 89ms/step - loss: 0.3845 - multimodal_head_loss: 0.1470 - distillation_head_loss: 0.2375 - multimodal_head_accuracy: 0.9558 - distillation_head_accuracy: 0.9327 - val_loss: 0.4052 - val_multimodal_head_loss: 0.1584 - val_distillation_head_loss: 0.2468 - val_multimodal_head_accuracy: 0.9563 - val_distillation_head_accuracy: 0.9297
# Epoch 27/30
# 3085/3085 [==============================] - 274s 89ms/step - loss: 0.3705 - multimodal_head_loss: 0.1371 - distillation_head_loss: 0.2335 - multimodal_head_accuracy: 0.9574 - distillation_head_accuracy: 0.9337 - val_loss: 0.4233 - val_multimodal_head_loss: 0.1701 - val_distillation_head_loss: 0.2532 - val_multimodal_head_accuracy: 0.9527 - val_distillation_head_accuracy: 0.9258
# Epoch 28/30
# 3085/3085 [==============================] - 276s 89ms/step - loss: 0.3742 - multimodal_head_loss: 0.1394 - distillation_head_loss: 0.2347 - multimodal_head_accuracy: 0.9569 - distillation_head_accuracy: 0.9334 - val_loss: 0.3966 - val_multimodal_head_loss: 0.1546 - val_distillation_head_loss: 0.2420 - val_multimodal_head_accuracy: 0.9618 - val_distillation_head_accuracy: 0.9310
# Epoch 29/30
# 3085/3085 [==============================] - 274s 89ms/step - loss: 0.3689 - multimodal_head_loss: 0.1352 - distillation_head_loss: 0.2338 - multimodal_head_accuracy: 0.9587 - distillation_head_accuracy: 0.9343 - val_loss: 0.4165 - val_multimodal_head_loss: 0.1649 - val_distillation_head_loss: 0.2516 - val_multimodal_head_accuracy: 0.9546 - val_distillation_head_accuracy: 0.9268
# Epoch 30/30
# 3085/3085 [==============================] - 277s 90ms/step - loss: 0.3722 - multimodal_head_loss: 0.1368 - distillation_head_loss: 0.2354 - multimodal_head_accuracy: 0.9580 - distillation_head_accuracy: 0.9332 - val_loss: 0.3960 - val_multimodal_head_loss: 0.1527 - val_distillation_head_loss: 0.2433 - val_multimodal_head_accuracy: 0.9540 - val_distillation_head_accuracy: 0.9303

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Embedding, Dense, Flatten, Concatenate, Conv2D, MaxPooling2D, Dropout, GlobalAveragePooling2D, LayerNormalization, Add, Reshape
from tensorflow.keras.models import Model

# --- Input Layers ---
mfcc_input = Input(shape=X_mfcc[0].shape)
fft_input = Input(shape=(X_fft[0].shape))

# --- MFCC and FFT Branches ---
# ... (Your existing code for MFCC and FFT branches) ...

# --- Multimodal and Distillation Heads ---
multimodal_head = Dense(2, activation='softmax', name='multimodal_head')(concat)
distillation_head = Dense(2, activation='softmax', name='distillation_head')(pvt_flat)

#Concatenate the outputs of the heads
concatenated_heads = Concatenate()([multimodal_head, distillation_head])

# %%
# --- Custom Dense Embedding Layer ---
embedding_dim = 32  # Adjust this based on your needs
embedding_layer = Dense(embedding_dim, activation='relu', name='embedding_layer')(concatenated_heads)

# --- Reshape for ViT input (adjust dimensions as needed) ---
vit_input_reshaped = Reshape((4, 8))(embedding_layer)

# %%
from tensorflow.keras import layers

class PVTBlock(layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, dropout_rate=0.1):
        super(PVTBlock, self).__init__()
        self.att = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = tf.keras.Sequential([
            layers.Dense(ff_dim, activation='relu'),
            layers.Dense(embed_dim)  # Output dimension should match embed_dim
        ])
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(dropout_rate)
        self.dropout2 = layers.Dropout(dropout_rate)
        # Add a projection layer to match the embedding dimension
        self.projection = layers.Dense(embed_dim)

    def call(self, inputs):
        # Project the input to match the embedding dimension
        projected_inputs = self.projection(inputs)
        attn_output = self.att(projected_inputs, projected_inputs)
        attn_output = self.dropout1(attn_output)
        out1 = self.layernorm1(projected_inputs + attn_output)  # Use projected_inputs here
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output)
        return self.layernorm2(out1 + ffn_output)  # Now shapes should match

# %%
# --- Input Layers ---
mfcc_input = Input(shape=(13, 130))
fft_input = Input(shape=(130,))

# --- MFCC and FFT Branches ---
mfcc_flatten = Flatten()(mfcc_input)
fft_flatten = Flatten()(fft_input)

concat = Concatenate()([mfcc_flatten, fft_flatten])
embedded = Dense(256, activation='relu')(concat)

# --- Multimodal and Distillation Heads ---
multimodal_head = Dense(2, activation='softmax', name='multimodal_head')(embedded)
distillation_head = Dense(2, activation='softmax', name='distillation_head')(embedded)

# Concatenate the outputs of the heads
concatenated_heads = Concatenate()([multimodal_head, distillation_head])

# --- Custom Dense Embedding Layer ---
embedding_dim = 32  # Adjust this based on your needs
embedding_layer = Dense(embedding_dim, activation='relu', name='embedding_layer')(concatenated_heads)

# Reshape embedding layer to match PVT block input requirements
embedding_layer_reshaped = Reshape((embedding_dim, 1))(embedding_layer)  # Adjust this as needed

# %%
def patch_embedding_layer(input_shape, patch_size, embed_dim):
    patches = tf.image.extract_patches(
        images=input_shape,
        sizes=[1, patch_size, patch_size, 1],
        strides=[1, patch_size, patch_size, 1],
        rates=[1, 1, 1, 1],
        padding='VALID',
    )
    n_p=patches.shape[-2]
    # Get the shape of the input tensor dynamically
    input_shape_val = tf.shape(input_shape)
    # patch = none , 8,8,768   # none=4
    patches = tf.reshape(patches, (-1,n_p*n_p* patch_size * patch_size * input_shape_val[-1])) # Use input_shape_val here
    # none  =
    return Dense(embed_dim)(patches)
t1=tf.ones(shape=(8,128,128,3))
q=Input(shape=(128,128,3))
m=Model(q,patch_embedding_layer(q,16,32))
m

# %%
m.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_14 (InputLayer)       [(None, 128, 128, 3)]        0         []
#
#  tf.compat.v1.shape_12 (TFO  (4,)                         0         ['input_14[0][0]']
#  pLambda)
#
#  tf.__operators__.getitem_9  ()                           0         ['tf.compat.v1.shape_12[0][0]'
#   (SlicingOpLambda)                                                 ]
#
#  tf.image.extract_patches_1  (None, 8, 8, 768)            0         ['input_14[0][0]']
#  1 (TFOpLambda)
#
#  tf.math.multiply_8 (TFOpLa  ()                           0         ['tf.__operators__.getitem_9[0
#  mbda)                                                              ][0]']
#
#  tf.reshape_10 (TFOpLambda)  (None, 49152)                0         ['tf.image.extract_patches_11[
#                                                                     0][0]',
#                                                                      'tf.math.multiply_8[0][0]']
#
#  dense_25 (Dense)            (None, 32)                   1572896   ['tf.reshape_10[0][0]']
#
# ==================================================================================================
# Total params: 1572896 (6.00 MB)
# Trainable params: 1572896 (6.00 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.layers import Input, Dense, Flatten, Reshape, Concatenate, GlobalAveragePooling1D, LayerNormalization, MultiHeadAttention, Add, Dropout, Lambda
from tensorflow.keras.models import Model
import tensorflow as tf

# Patch Embedding Layer
def patch_embedding_layer(input_shape, patch_size, embed_dim):
    patches = tf.image.extract_patches(
        images=input_shape,
        sizes=[1, patch_size, patch_size, 1],
        strides=[1, patch_size, patch_size, 1],
        rates=[1, 1, 1, 1],
        padding='VALID',
    )
    # Get the shape of the input tensor dynamically
    input_shape_val = tf.shape(input_shape)
    # patch = none , 8,8,768   # none=4
    patches = tf.reshape(patches, (-1, patch_size * patch_size * input_shape_val[-1])) # Use input_shape_val here ----------------------------" error line "
    # none  =
    return Dense(embed_dim)(patches)

128*128*3
16
# Define the input shape for the Vision Transformer
vit_input = Input(shape=(128, 128, 3))

# Convert image to patches
patch_size = 16  # Example patch size
embed_dim = 32  # Example embedding dimension

# Patch embedding
patches = patch_embedding_layer(vit_input, patch_size=patch_size, embed_dim=embed_dim)

# Calculate the number of patches correctly
num_patches = (tf.shape(vit_input)[1] // patch_size) * (tf.shape(vit_input)[2] // patch_size)

# Reshape with the correct number of patches using a Lambda layer
# Use tf.shape to get the dynamic shape of the patches tensor
patches = Lambda(lambda x: tf.reshape(x, (-1, tf.cast(tf.shape(x)[0] // embed_dim, tf.int32), embed_dim)))(patches)

# Apply PVT Blocks
x = PVTBlock(embed_dim=embed_dim, num_heads=4, ff_dim=128)(patches)
x = PVTBlock(embed_dim=embed_dim, num_heads=4, ff_dim=128)(x)

# Add Transformer Encoder layers
def transformer_encoder(x, num_heads, ff_dim):
    attn_output = MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)(x, x)
    attn_output = Add()([x, attn_output])
    attn_output = LayerNormalization()(attn_output)

    ffn_output = Dense(ff_dim, activation='relu')(attn_output)
    ffn_output = Dense(embed_dim)(ffn_output)
    x = Add()([attn_output, ffn_output])
    return LayerNormalization()(x)

# Apply transformer encoders
num_transformer_layers = 2
for _ in range(num_transformer_layers):
    print(x)
    x = transformer_encoder(x, num_heads=4, ff_dim=128)

# Global Average Pooling
x = GlobalAveragePooling1D()(x)

# Combine with another embedding layer if needed
embedding_layer = Dense(128)(x)  # Example embedding layer

# Final classification head
output = Dense(2, activation='softmax', name='final_output')(embedding_layer)

# %%
model = Model(inputs=[mfcc_input, fft_input, vit_input], outputs=output)
model.summaary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-085d23aa14c1> in <cell line: 1>()
# ----> 1 model = Model(inputs=[mfcc_input, fft_input, vit_input], outputs=output)
#       2 model.summaary()
#
# NameError: name 'mfcc_input' is not defined

# %%
# Define the final model
model = Model(inputs=[mfcc_input, fft_input, vit_input], outputs=output)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of the model
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_7 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  tf.compat.v1.shape (TFOpLa  (4,)                         0         ['input_7[0][0]']
#  mbda)
#
#  tf.__operators__.getitem (  ()                           0         ['tf.compat.v1.shape[0][0]']
#  SlicingOpLambda)
#
#  tf.image.extract_patches (  (None, 8, 8, 768)            0         ['input_7[0][0]']
#  TFOpLambda)
#
#  tf.math.multiply (TFOpLamb  ()                           0         ['tf.__operators__.getitem[0][
#  da)                                                                0]']
#
#  tf.reshape (TFOpLambda)     (None, 768)                  0         ['tf.image.extract_patches[0][
#                                                                     0]',
#                                                                      'tf.math.multiply[0][0]']
#
#  dense_4 (Dense)             (None, 32)                   24608     ['tf.reshape[0][0]']
#
#  lambda (Lambda)             (None, None, 32)             0         ['dense_4[0][0]']
#
#  pvt_block (PVTBlock)        (None, None, 32)             26336     ['lambda[0][0]']
#
#  pvt_block_1 (PVTBlock)      (None, None, 32)             26336     ['pvt_block[0][0]']
#
#  multi_head_attention_2 (Mu  (None, None, 32)             16800     ['pvt_block_1[0][0]',
#  ltiHeadAttention)                                                   'pvt_block_1[0][0]']
#
#  add_1 (Add)                 (None, None, 32)             0         ['pvt_block_1[0][0]',
#                                                                      'multi_head_attention_2[0][0]
#                                                                     ']
#
#  layer_normalization_7 (Lay  (None, None, 32)             64        ['add_1[0][0]']
#  erNormalization)
#
#  dense_11 (Dense)            (None, None, 128)            4224      ['layer_normalization_7[0][0]'
#                                                                     ]
#
#  dense_12 (Dense)            (None, None, 32)             4128      ['dense_11[0][0]']
#
#  add_2 (Add)                 (None, None, 32)             0         ['layer_normalization_7[0][0]'
#                                                                     , 'dense_12[0][0]']
#
#  layer_normalization_8 (Lay  (None, None, 32)             64        ['add_2[0][0]']
#  erNormalization)
#
#  multi_head_attention_3 (Mu  (None, None, 32)             16800     ['layer_normalization_8[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_8[0][0]
#                                                                     ']
#
#  add_3 (Add)                 (None, None, 32)             0         ['layer_normalization_8[0][0]'
#                                                                     , 'multi_head_attention_3[0][0
#                                                                     ]']
#
#  layer_normalization_9 (Lay  (None, None, 32)             64        ['add_3[0][0]']
#  erNormalization)
#
#  dense_13 (Dense)            (None, None, 128)            4224      ['layer_normalization_9[0][0]'
#                                                                     ]
#
#  dense_14 (Dense)            (None, None, 32)             4128      ['dense_13[0][0]']
#
#  add_4 (Add)                 (None, None, 32)             0         ['layer_normalization_9[0][0]'
#                                                                     , 'dense_14[0][0]']
#
#  layer_normalization_10 (La  (None, None, 32)             64        ['add_4[0][0]']
#  yerNormalization)
#
#  global_average_pooling1d (  (None, 32)                   0         ['layer_normalization_10[0][0]
#  GlobalAveragePooling1D)                                            ']
#
#  dense_15 (Dense)            (None, 128)                  4224      ['global_average_pooling1d[0][
#                                                                     0]']
#
#  input_5 (InputLayer)        [(None, 13, 130)]            0         []
#
#  input_6 (InputLayer)        [(None, 130)]                0         []
#
#  final_output (Dense)        (None, 2)                    258       ['dense_15[0][0]']
#
# ==================================================================================================
# Total params: 132322 (516.88 KB)
# Trainable params: 132322 (516.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.layers import Input, Dense, GlobalAveragePooling1D, LayerNormalization, MultiHeadAttention, Add, Lambda, Reshape
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
import tensorflow as tf
# Print model graph
plot_model(model, show_shapes=True, show_layer_names=True)

# %%
# import os
# import cv2
# import numpy as np
# from scipy.fftpack import fft
# from scipy.signal import butter, lfilter
# import librosa
# import zipfile

# # Function to extract MFCC and FFT features from an image
# def extract_mfcc_fft(image):
#     # Example: feature extraction logic
#     image_gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
#     signal = image_gray.mean(axis=0)

#     # Example: high-pass filter
#     cutoff_freq = 100
#     nyquist_freq = 0.5 * 22050
#     normal_cutoff = cutoff_freq / nyquist_freq
#     b, a = butter(4, normal_cutoff, btype='high', analog=False)
#     filtered_signal = lfilter(b, a, signal)

#     n_fft = min(2048, len(filtered_signal))
#     mfccs = librosa.feature.mfcc(y=filtered_signal, sr=22050, n_mfcc=13, n_fft=n_fft)
#     fft_features = np.abs(fft(filtered_signal, n=n_fft))

#     return mfccs, fft_features, image

# # Function to save features to zip
# def save_features_to_zip(features, zip_filename):
#     with zipfile.ZipFile(zip_filename, 'w') as zipf:
#         for idx, (mfcc, fft, image) in enumerate(features):
#             # Define filenames for each feature and image
#             mfcc_filename = f'{idx}_mfcc.npy'
#             fft_filename = f'{idx}_fft.npy'
#             image_filename = f'{idx}_image.jpg'

#             # Save MFCC, FFT, and image to zip file
#             np.save(zipf, mfcc_filename, mfcc)
#             np.save(zipf, fft_filename, fft)
#             cv2.imwrite(image_filename, image)

# # Step 1: Define paths to your zip files
# real_zip_path = '/content/drive/MyDrive/Celeb-DF/Frames-Real-20240626T130257Z-001.zip'
# fake_zip_path = '/content/drive/MyDrive/Celeb-DF/Frames-Fake-20240626T130258Z-001.zip'

# # Step 2: Unzip the files
# real_extract_path = '/content/Frames-Real'
# fake_extract_path = '/content/Frames-Fake'

# !unzip -q -o '{real_zip_path}' -d '{real_extract_path}'
# !unzip -q -o '{fake_zip_path}' -d '{fake_extract_path}'

# # Function to process images from a directory and extract features
# def process_images_and_extract_features(image_dir):
#     features = []
#     for subdir, dirs, files in os.walk(image_dir):
#         for filename in files:
#             image_path = os.path.join(subdir, filename)
#             try:
#                 image = cv2.imread(image_path)
#                 if image is None:
#                     print(f"Error reading image: {image_path}")
#                     continue

#                 image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

#                 mfcc, fft, processed_image = extract_mfcc_fft(image)
#                 features.append((mfcc, fft, processed_image))

#             except Exception as e:
#                 print(f"Error processing image: {image_path}, Error: {str(e)}")
#                 continue

#     return features

# # Process real images
# real_features = process_images_and_extract_features(real_extract_path)

# # Process fake images
# fake_features = process_images_and_extract_features(fake_extract_path)

# # Step 3: Save extracted features to zip files
# real_zip_filename = '/content/drive/MyDrive/Celeb-DF/Real_Extracted_Features.zip'
# fake_zip_filename = '/content/drive/MyDrive/Celeb-DF/Fake_Extracted_Features.zip'

# save_features_to_zip(real_features, real_zip_filename)
# save_features_to_zip(fake_features, fake_zip_filename)

# print(f"Real features saved to '{real_zip_filename}'")
# print(f"Fake features saved to '{fake_zip_filename}'")

# %%
import os
import cv2
import numpy as np
from sklearn.utils import shuffle
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf

# Step 1: Mount Google Drive (assuming already done)

# Step 2: Define paths to your zip files (already defined)
real_zip_path = '/content/drive/MyDrive/Celeb-DF/Frames-Real-20240626T130257Z-001.zip'
fake_zip_path = '/content/drive/MyDrive/Celeb-DF/Frames-Fake-20240626T130258Z-001.zip'

# Step 3: Unzip the files (already done)
# !unzip -q -o '{real_zip_path}' -d '/content/Frames-Real'
# !unzip -q -o '{fake_zip_path}' -d '/content/Frames-Fake'

# --- Data Generators ---
datagen = ImageDataGenerator(rescale=1./255)

# Define batch size for generators
batch_size = 4

real_generator = datagen.flow_from_directory(
    directory='/content/Frames-Real',
    target_size=(128, 128),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=True
)

fake_generator = datagen.flow_from_directory(
    directory='/content/Frames-Fake',
    target_size=(128, 128),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=True
)

def combined_generator(real_gen, fake_gen):
    while True:
        # Get batches from both generators simultaneously
        real_data, real_labels = next(real_gen) # batch size =4
        fake_data, fake_labels = next(fake_gen)

        # Combine batches (assuming dummy data for MFCC and FFT for now)
        batch_size = real_data.shape[0]  # Get the batch size from the generator
        mfcc_data = np.zeros((batch_size * 2, 13, 130))  # Replace with actual MFCC data
        fft_data = np.zeros((batch_size * 2, 130))        # Replace with actual FFT data
        combined_images = np.concatenate((real_data, fake_data), axis=0)
        combined_labels = np.concatenate((real_labels, fake_labels), axis=0)

        # Shuffle combined batch
        combined_images, combined_labels, mfcc_data, fft_data = shuffle(
            combined_images, combined_labels, mfcc_data, fft_data, random_state=42
        )

        # Convert labels to one-hot encoding **after** determining the correct batch size
        combined_labels = tf.keras.utils.to_categorical(combined_labels, num_classes=2)

        # Yield combined batch with the correct batch size for labels
        yield [mfcc_data, fft_data, combined_images], combined_labels[:batch_size * 2]  # Yield combined batch with sliced labels

# Combined generator
combined_gen = combined_generator(real_generator, fake_generator)
# Out:
# Found 2538 images belonging to 1 classes.
# Found 12888 images belonging to 1 classes.

# %%
@tf.function
def train_step(inputs, labels):
    with tf.GradientTape() as tape:
        predictions = model(inputs, training=True)

        # Ensure both labels and predictions are float32
        labels = tf.cast(labels, tf.float32)
        predictions = tf.cast(predictions, tf.float32)

        # Print shapes and types for debugging
        print("Labels shape:", labels.shape)
        print("Predictions shape:", predictions.shape)
        print("Labels dtype:", labels.dtype)
        print("Predictions dtype:", predictions.dtype)

        # Compute categorical crossentropy loss
        loss = tf.keras.losses.categorical_crossentropy(labels, predictions)

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
import os

# Function to print the shapes of inputs and labels from the generator
def print_generator_shapes(generator, name):
    for inputs, labels in generator:
        if isinstance(inputs, list):
            print(f"Shapes of {name} inputs:")
            for i, input_tensor in enumerate(inputs):
                print(f"  Input {i+1} shape: {input_tensor.shape}")
        else:
            print(f"Shape of {name} inputs:", inputs.shape)

        if isinstance(labels, list):
            print(f"Shapes of {name} labels:")
            for i, label_tensor in enumerate(labels):
                print(f"  Label {i+1} shape: {label_tensor.shape}")
        else:
            print(f"Shape of {name} labels:", labels.shape)
        break  # Print the shapes for the first batch only

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Set the number of epochs per batch
epochs_per_batch = 2  # Number of epochs to run in each batch
total_epochs = 4   # Total number of epochs to train the model

# Define checkpoint callback to save the model weights
checkpoint_cb = ModelCheckpoint('model_checkpoint.h5', save_best_only=True, save_weights_only=True)

# Load weights if continuing training from a checkpoint
try:
    model.load_weights('model_checkpoint.h5')
    print("Checkpoint loaded. Continuing training from last saved epoch.")
except Exception as e:
    print("No checkpoint found. Starting training from scratch.")

# Print the shapes of the inputs and labels to check for any mismatches
print_generator_shapes(combined_gen, "training")
print_generator_shapes(combined_gen, "validation")

# Train the model in smaller batches
current_epoch = 0
while current_epoch < total_epochs:
    print(f"Training epochs {current_epoch+1} to {current_epoch+epochs_per_batch}...")

    for inputs, labels in combined_gen:
        # Convert labels to float32 explicitly
        labels = tf.cast(labels, tf.float32)

        # Compute loss and update gradients
        with tf.GradientTape() as tape:
            predictions = model(inputs, training=True)
            loss = tf.keras.losses.categorical_crossentropy(labels, predictions)
        gradients = tape.gradient(loss, model.trainable_variables)
        optimizer.apply_gradients(zip(gradients, model.trainable_variables))

        # Print loss or other metrics as needed
        print(f"Loss: {loss.numpy()}")

        # Break the loop after one batch (epochs_per_batch should handle epoch count)
        break

    # Increment the current epoch counter
    current_epoch += epochs_per_batch

    # Save the model weights after each batch of epochs
    model.save_weights(f'model_weights_epoch_{current_epoch}.h5')
    print(f"Model weights saved for epoch {current_epoch}.")

print("Training complete.")
# Out:
# No checkpoint found. Starting training from scratch.
# Shapes of training inputs:
#   Input 1 shape: (8, 13, 130)
#   Input 2 shape: (8, 130)
#   Input 3 shape: (8, 128, 128, 3)
# Shape of training labels: (8, 2)
# Shapes of validation inputs:
#   Input 1 shape: (8, 13, 130)
#   Input 2 shape: (8, 130)
#   Input 3 shape: (8, 128, 128, 3)
# Shape of validation labels: (8, 2)
# Training epochs 1 to 2...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-f242ec018a60> in <cell line: 46>()
#      54         with tf.GradientTape() as tape:
#      55             predictions = model(inputs, training=True)
# ---> 56             loss = tf.keras.losses.categorical_crossentropy(labels, predictions)
#      57         gradients = tape.gradient(loss, model.trainable_variables)
#      58         optimizer.apply_gradients(zip(gradients, model.trainable_variables))
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
#     155       del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/losses.py in categorical_crossentropy(y_true, y_pred, from_logits, label_smoothing, axis)
#    2219     )
#    2220
# -> 2221     return backend.categorical_crossentropy(
#    2222         y_true, y_pred, from_logits=from_logits, axis=axis
#    2223     )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py in categorical_crossentropy(target, output, from_logits, axis)
#    5571     target = tf.convert_to_tensor(target)
#    5572     output = tf.convert_to_tensor(output)
# -> 5573     target.shape.assert_is_compatible_with(output.shape)
#    5574
#    5575     output, from_logits = _get_logits(
#
# ValueError: Shapes (8, 2) and (32, 2) are incompatible

# %%
# import os
# import cv2
# import numpy as np
# from sklearn.utils import shuffle
# import tensorflow as tf
# from tensorflow.keras.callbacks import ModelCheckpoint
# from tensorflow.keras.utils import to_categorical

# # Step 1: Mount Google Drive (assuming already done)

# # Step 2: Define paths to your zip files (already defined)
# real_zip_path = '/content/drive/MyDrive/Celeb-DF/Frames-Real-20240626T130257Z-001.zip'
# fake_zip_path = '/content/drive/MyDrive/Celeb-DF/Frames-Fake-20240626T130258Z-001.zip'

# # Step 3: Unzip the files (already done)
# !unzip -q -o '{real_zip_path}' -d '/content/Frames-Real'
# !unzip -q -o '{fake_zip_path}' -d '/content/Frames-Fake'

# def load_images_from_dir(directory, target_size=(128, 128)):
#     images = []
#     labels = []

#     for filename in os.listdir(directory):
#         if filename.endswith(".jpg") or filename.endswith(".png"):
#             img = cv2.imread(os.path.join(directory, filename))
#             if img is None:
#                 print(f"Failed to load image: {filename}")
#                 continue
#             img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert to RGB
#             img = cv2.resize(img, target_size)  # Resize to target size
#             img = img / 255.0  # Normalize pixel values to [0, 1]
#             images.append(img)
#             labels.append(0 if "Frames-Real" in directory else 1)  # 0 for real, 1 for fake

#     return np.array(images), np.array(labels)

# # Test loading function for real images
# real_images, real_labels = load_images_from_dir('/content/Frames-Real')
# print(f"Number of real images: {len(real_images)}")

# # Test loading function for fake images
# fake_images, fake_labels = load_images_from_dir('/content/Frames-Fake')
# print(f"Number of fake images: {len(fake_images)}")


# # Load real and fake images
# real_images, real_labels = load_images_from_dir('/content/drive/MyDrive/Celeb-DF/Frames-Real')
# fake_images, fake_labels = load_images_from_dir('/content/drive/MyDrive/Celeb-DF/Frames-Fake')

# # Combine images and labels
# combined_images = np.concatenate((real_images, fake_images), axis=0)
# combined_labels = np.concatenate((real_labels, fake_labels), axis=0)

# # Shuffle combined data
# combined_images, combined_labels = shuffle(combined_images, combined_labels, random_state=42)

# # Convert labels to one-hot encoding
# combined_labels = to_categorical(combined_labels, num_classes=2)

# # Split into training and validation sets (adjust split ratio as needed)
# split_ratio = 0.8
# split_idx = int(len(combined_images) * split_ratio)

# train_images, val_images = combined_images[:split_idx], combined_images[split_idx:]
# train_labels, val_labels = combined_labels[:split_idx], combined_labels[split_idx:]

# # Example: Print shapes of loaded data
# print(f"Shapes of training inputs: {train_images.shape}")
# print(f"Shapes of training labels: {train_labels.shape}")
# print(f"Shapes of validation inputs: {val_images.shape}")
# print(f"Shapes of validation labels: {val_labels.shape}")

# %%
# # Check Data Generators: Ensure both combined_gen and fake_generator produce batches with the same batch size (4 in your case).
# def check_batch_sizes(generator):
#     for inputs, labels in generator:
#         batch_size = len(inputs)  # Assuming inputs is a list or array
#         return batch_size

# batch_size_combined_gen = check_batch_sizes(combined_gen)
# batch_size_fake_gen = check_batch_sizes(fake_generator)

# print(f"Batch size of combined_gen: {batch_size_combined_gen}")
# print(f"Batch size of fake_generator: {batch_size_fake_gen}")

# # Compare batch sizes and raise an error if they don't match
# if batch_size_combined_gen != batch_size_fake_gen:
#     raise ValueError("Batch sizes of combined_gen and fake_generator do not match!")

# # If batch sizes match, continue with training setup
# steps_per_epoch = len(real_generator)  # Adjust this to the correct number of batches
# validation_steps = len(fake_generator)  # Adjust this to the correct number of batches
